# %%
import torch
import time
import pandas as pd
import numpy as np

import os
import sys
sys.path.append('..')
from src.wrapper import end2end
from src.utils import get_topic_diversity, get_topic_coherence

etm = end2end(min_df=0.005)
etm.load_model("weights/dan_etm_20ng_500topics_mindf0.005")
# Out:
# success: model and preprocessor loaded from weights/dan_etm_20ng_500topics_mindf0.005

# %%
etm.top_k_words()
# Out:
# Topic 0: ['distribution', 'netcom', 'access', 'posting', 'nntp', 'net', 'freenet', 'digex', 'services']
# Topic 1: ['years', 'time', 'ago', 'year', 'long', 'back', 'good', 'times', 'days']
# Topic 2: ['opinions', 'heard', 'find', 'mine', 'appears', 'good', 'work', 'case', 'knowledge']
# Topic 3: ['org', 'world', 'david', 'usa', 'posting', 'bob', 'bbs', 'net', 'keywords']
# Topic 4: ['fbi', 'fire', 'apple', 'stratus', 'sandvik', 'gatech', 'corporation', 'kent', 'death']
# Topic 5: ['windows', 'software', 'dos', 'version', 'unix', 'ibm', 'ms', 'pub', 'comp']
# Topic 6: ['power', 'ground', 'water', 'cable', 'current', 'wire', 'pin', 'supply', 'circuit']
# Topic 7: ['israel', 'turkish', 'jews', 'armenian', 'israeli', 'armenians', 'jewish', 'war', 'people']
# Topic 8: ['number', 'line', 'entry', 'info', 'include', 'call', 'note', 'section', 'return']
# Topic 9: ['money', 'clinton', 'work', 'people', 'care', 'tax', 'insurance', 'pay', 'government']
# ...

# %%
etm.visualize_topic_embeddings(topic_idx =7, n=17, alpha=0.7, size=35)
# Out:
# Topic 7: ['israel', 'turkish', 'jews', 'armenian', 'israeli', 'armenians', 'jewish', 'war', 'people', 'armenia', 'arab', 'greek', 'turks', 'peace', 'turkey', 'world', 'muslim']

# %%
etm.visualize_topic_embeddings?
