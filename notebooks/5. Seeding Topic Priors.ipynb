# %%
import torch
import time
import numpy as np

import os
import sys
sys.path.append('..')
from src.wrapper import end2end
from src.utils import get_topic_diversity, get_topic_coherence

# %% [markdown]
# ### Can we initialize topic representations from a seeded list?

# %%
import pandas as pd
movies = pd.read_csv('../data/movies/movies.csv')
train_data = movies.overview.tolist()

# %%
etm = end2end(num_topics=6, min_df=0.001)
etm.fit(movies.overview.tolist(), 
        embeddings = 'GoogleNews-vectors-negative300.magnitude',
        verbose=1)
# Out:
# torch.Size([21330, 4272])
# torch.Size([21330, 4272])
# Preprocessor: 4272 words saved
# Pretrained embeddings loaded: 4260 / 4272
# Epoch: 0 .. batch: 2/22 .. LR: 0.005 .. KL_theta: 0.01 .. Rec_loss: 168.54 .. NELBO: 168.55
# Epoch: 0 .. batch: 4/22 .. LR: 0.005 .. KL_theta: 0.01 .. Rec_loss: 168.89 .. NELBO: 168.9
# Epoch: 0 .. batch: 6/22 .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 170.07 .. NELBO: 170.07
# Epoch: 0 .. batch: 8/22 .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 169.49 .. NELBO: 169.49
# Epoch: 0 .. batch: 10/22 .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 169.51 .. NELBO: 169.51
# Epoch: 0 .. batch: 12/22 .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 170.03 .. NELBO: 170.03
# Epoch: 0 .. batch: 14/22 .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 170.36 .. NELBO: 170.36
# Epoch: 0 .. batch: 16/22 .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 169.87 .. NELBO: 169.87
# Epoch: 0 .. batch: 18/22 .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 169.38 .. NELBO: 169.38
# ...

# %%
etm.evaluate()
# etm.save_model('unseeded_movies')
# Out:
# Topic diveristy is: 0.9733333333333334
# (0.9733333333333334, 0.07566020886893952, 0.07364260329910115)

# %%
etm = end2end(num_topics=6, min_df=0.001)
etm.load_model('unseeded_movies')
etm.top_k_words(n=10)
# Out:
# Topic 0: ['young', 'love', 'woman', 'family', 'life', 'years', 'man', 'wife', 'girl']
# Topic 1: ['town', 'small', 'city', 'past', 'john', 'money', 'york', 'big', 'local']
# Topic 2: ['man', 'police', 'murder', 'gang', 'killer', 'crime', 'men', 'named', 'detective']
# Topic 3: ['film', 'story', 'world', 'set', 'high', 'movie', 'based', 'star', 'game']
# Topic 4: ['life', 'time', 'find', 'finds', 'back', 'takes', 'day', 'meets', 'make']
# Topic 5: ['war', 'group', 'world', 'american', 'battle', 'team', 'secret', 'fight', 'army']

# %% [markdown]
# ### Now to seed the model

# %%
import torch
import time
import numpy as np

import os
import sys
sys.path.append('..')
from src.wrapper import end2end
from src.utils import get_topic_diversity, get_topic_coherence

import pandas as pd
movies = pd.read_csv('../data/movies/movies.csv')
train_data = movies.overview.tolist()

seed_topic_list=[['spy','mafia','fighter','warrior', 'china', 'master'],
                 ['wedding','date','friendship','summer','sex','romantic',
                  'divorce','musical','married','love','teenage'],
                 ['space', 'astornaut','spaceship','galaxy','moon','universe',
                  'robot',' creature','unknown','mutate','lab'],
                 ['spy','hostage','investigation','accident','pursuit','supernatural',
                  'terrorize','fbi','witness','murder','justice','witness'],
                 ['nazi','camp','troop','allied','general','war','prisoner','raid'],
                 ['sheriff', 'gunslinger','revolver','chief','cowboy','gold','wagon']
                ]

etm = end2end(num_topics=6, min_df=0.001)
etm.fit(movies.overview.tolist(), 
        magnitude = 'GoogleNews-vectors-negative300.magnitude',
        seed_topic_list=seed_topic_list,
        verbose=1)
# Out:
# Preprocessor: 4272 words saved
# Pretrained embeddings loaded: 4260 / 4272
# Epoch: 0 .. batch: 2/22 .. LR: 0.005 .. KL_theta: 0.01 .. Rec_loss: 168.4 .. NELBO: 168.41
# Epoch: 0 .. batch: 4/22 .. LR: 0.005 .. KL_theta: 0.01 .. Rec_loss: 168.75 .. NELBO: 168.76
# Epoch: 0 .. batch: 6/22 .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 169.94 .. NELBO: 169.94
# Epoch: 0 .. batch: 8/22 .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 169.36 .. NELBO: 169.36
# Epoch: 0 .. batch: 10/22 .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 169.38 .. NELBO: 169.38
# Epoch: 0 .. batch: 12/22 .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 169.9 .. NELBO: 169.9
# Epoch: 0 .. batch: 14/22 .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 170.22 .. NELBO: 170.22
# Epoch: 0 .. batch: 16/22 .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 169.74 .. NELBO: 169.74
# Epoch: 0 .. batch: 18/22 .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 169.25 .. NELBO: 169.25
# ...

# %%
# etm.save_model('seeded_movies')
etm.top_k_words(n=10)
# Out:
# Topic 0: ['town', 'finds', 'time', 'takes', 'school', 'life', 'meets', 'small', 'friends']
# Topic 1: ['love', 'young', 'life', 'family', 'woman', 'wife', 'years', 'father', 'girl']
# Topic 2: ['world', 'past', 'people', 'mysterious', 'save', 'life', 'find', 'earth', 'discover']
# Topic 3: ['man', 'police', 'murder', 'men', 'gang', 'crime', 'death', 'named', 'killer']
# Topic 4: ['war', 'group', 'american', 'secret', 'based', 'army', 'team', 'fight', 'stop']
# Topic 5: ['film', 'story', 'york', 'movie', 'stars', 'series', 'john', 'star', 'london']

# %%
import torch
import time
import numpy as np

import os
import sys
sys.path.append('..')
from src.wrapper import end2end
from src.utils import get_topic_diversity, get_topic_coherence

import pandas as pd
movies = pd.read_csv('../data/movies/movies.csv')
train_data = movies.overview.tolist()

seed_topic_list=[['action','spy','mafia','fighter','warrior', 'police', 'cop'],
                 ['romance','sex'],
                 ['science_fiction'],
                 ['thriller','deadly','tension'],
                 ['war','nazi','troop','general','prisoner','raid'],
                 ['cowboy','sheriff'],
                 ['movie','starring','stars','actors','film']
                ]

etm = end2end(num_topics=7, min_df=0.001)
etm.fit(movies.overview.tolist(), 
        magnitude = 'GoogleNews-vectors-negative300.magnitude',
        seed_topic_list=seed_topic_list,
        epochs=10,
        verbose=1)
# Out:
# Preprocessor: 4272 words saved
# Pretrained embeddings loaded: 4260 / 4272
# Epoch: 0 .. batch: 2/22 .. LR: 0.005 .. KL_theta: 0.01 .. Rec_loss: 171.23 .. NELBO: 171.24
# Epoch: 0 .. batch: 4/22 .. LR: 0.005 .. KL_theta: 0.01 .. Rec_loss: 171.31 .. NELBO: 171.32
# Epoch: 0 .. batch: 6/22 .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 171.11 .. NELBO: 171.11
# Epoch: 0 .. batch: 8/22 .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 171.37 .. NELBO: 171.37
# Epoch: 0 .. batch: 10/22 .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 170.99 .. NELBO: 170.99
# Epoch: 0 .. batch: 12/22 .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 170.91 .. NELBO: 170.91
# Epoch: 0 .. batch: 14/22 .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 170.14 .. NELBO: 170.14
# Epoch: 0 .. batch: 16/22 .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 169.79 .. NELBO: 169.79
# Epoch: 0 .. batch: 18/22 .. LR: 0.005 .. KL_theta: 0.0 .. Rec_loss: 169.69 .. NELBO: 169.69
# ...

# %%
# etm.save_model('seeded_movies')
etm.top_k_words(n=10)
# Out:
# Topic 0: ['man', 'police', 'woman', 'crime', 'murder', 'detective', 'murdered', 'cop', 'cops']
# Topic 1: ['love', 'young', 'life', 'family', 'mother', 'daughter', 'woman', 'girl', 'lives']
# Topic 2: ['world', 'life', 'planet', 'time', 'earth', 'day', 'mankind', 'country', 'lives']
# Topic 3: ['find', 'finds', 'man', 'home', 'life', 'turns', 'finding', 'back', 'ends']
# Topic 4: ['war', 'military', 'army', 'fight', 'combat', 'wars', 'battle', 'forces', 'fighting']
# Topic 5: ['man', 'woman', 'town', 'boy', 'police', 'city', 'person', 'home', 'house']
# Topic 6: ['film', 'movie', 'story', 'documentary', 'films', 'filmmaker', 'tale', 'life', 'thriller']

# %% [markdown]
# Eyeball the model.

# %%
movies[movies.Western==1]#.iloc[1].overview
# Out:
#                                                 overview  Action  Romance  \
# 114    Biopic about famous gunslinger Wild Bill Hicko...       1        0
# 168    A mysterious woman comes to compete in a quick...       1        0
# 204    Maverick is a gambler who would rather con som...       1        0
# 212    Covering the life and times of one of the West...       1        0
# 230    Four former harlots try to leave the wild west...       1        0
# ...                                                  ...     ...      ...
# 20064  A crotchety old ranch owner fights to be able ...       0        0
# 20107  A good-natured cowboy who is romancing the new...       0        0
# 20123  Legendary Lawman and Gunslinger Wild Bill Hick...       0        0
# 20124  The last Gunslinger, Roland Deschain, has been...       1        0
# 20221  It's the Old Western times and an outlaw named...       0        0
#
#        Science Fiction  Thriller  War  Western
# ...

# %%
idx=203
print(movies.overview[idx])
display(movies.iloc[idx,1:])
etm.predict_proba([movies.overview[idx]])[0,:6]
# Out:
# When timid bank clerk Stanley Ipkiss discovers a magical mask containing the spirit of the Norse god Loki, his entire life changes. While wearing the mask, Ipkiss becomes a supernatural playboy exuding charm and confidence which allows him to catch the eye of local nightclub singer Tina Carlyle. Unfortunately, under the mask's influence, Ipkiss also robs a bank, which angers junior crime lord Dorian Tyrell, whose goons get blamed for the heist.
# Action             0
# Romance            1
# Science Fiction    0
# Thriller           0
# War                0
# Western            0
# Name: 203, dtype: object
# tensor([0.5910, 0.5297, 0.4613, 0.4933, 0.3563, 0.5718], device='cuda:0',
#        grad_fn=<SliceBackward>)

# %% [markdown]
# ### Check w2v vocab

# %%
from pymagnitude import *
w2v = Magnitude('GoogleNews-vectors-negative300.magnitude')
'wild_west' in w2v
# Out:
# False

# %% [markdown]
# ### Viewing model topic models quality

# %%
# etm.save_model('seeded_movies')
etm.top_k_words(n=10)
# Out:
# Topic 0: ['york', 'john', 'dr', 'michael', 'jack', 'king', 'french', 'mr', 'david']
# Topic 1: ['love', 'young', 'life', 'woman', 'family', 'wife', 'father', 'years', 'girl']
# Topic 2: ['world', 'film', 'story', 'set', 'life', 'movie', 'based', 'earth', 'series']
# Topic 3: ['man', 'police', 'murder', 'find', 'gang', 'killer', 'crime', 'men', 'death']
# Topic 4: ['war', 'group', 'american', 'secret', 'army', 'fight', 'battle', 'team', 'military']
# Topic 5: ['town', 'school', 'time', 'meets', 'city', 'small', 'find', 'high', 'night']

# %%
etm.evaluate()
# Out:
# Topic diveristy is: 0.9714285714285714
# (0.9714285714285714, 0.07219130907491857, 0.0701287002442066)

# %% [markdown]
# ### Appendix

# %%
from pymagnitude import *
magnitude = Magnitude('GoogleNews-vectors-negative300.magnitude')

etm = end2end()
etm.load_model('w_kullback_w_word2vec')

seed_topic_list = [['game', 'team', 'win', 'player', 'season', 'second', 'victory'],
                   ['percent', 'company', 'market', 'price', 'sell', 'business', 'stock', 'share'],
                   ['music', 'write', 'art', 'book', 'world', 'film'],
                   ['political', 'government', 'leader', 'official', 'state', 'country', 'american','case', 'law', 'police', 'charge', 'officer', 'kill', 'arrest', 'lawyer']]

# %%
seed_topic = seed_topic_list[0]

for idx, seed_topic in enumerate(seed_topic_list):
    # get mean of seeded word embeddings
    init_topic = [torch.from_numpy(magnitude.query(seed)).type(torch.cuda.FloatTensor).view(1,-1) 
              for seed in seed_topic]
    init_topic = torch.cat(init_topic, axis=0).mean(axis=0)
    
    # change weights of the topic embedding
    # https://discuss.pytorch.org/t/how-to-manually-set-the-weights-in-a-two-layer-linear-model/45902
    with torch.no_grad():
        etm.model.topic_embed.weight[idx,:] = init_topic
